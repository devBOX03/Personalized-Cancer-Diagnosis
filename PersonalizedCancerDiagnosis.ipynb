# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from tqdm import tqdm

# %% [markdown]
# <h2>3.1. Reading Data </h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training/training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training/training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 236.996149 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# #### Feature Engineering :
# - The below code snippet is performing feature engineering.
# - It is replacing Variations with single occurence with it's corresponding Gene value.
# - It provides a upperhand to the model for choosing the right class.

# %%
# The below code snippet is performing feature engineering
# It is replacing Variations with single occurence with it's corresponding Gene value
# It provides a upperhand to the model for choosing the right class.

variation_dict = result['Variation'].value_counts() # find unique variations
unique_variations = []

for key, value in variation_dict.items(): 
  if value == 1: # Finding Variations wit single occurence
    unique_variations.append(key)
    
# replacing Variations with single occurence with it's corresponding Gene value
result.loc[result['Variation'].isin(unique_variations),'Variation'] = result['Gene']
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                   CBL      2
# 2   2     CBL                   CBL      2
# 3   3     CBL                   CBL      3
# 4   4     CBL                   CBL      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

def datasetDistributions(class_distribution, data_df, type_of_data):
    my_colors = 'rgbkymc'
    class_distribution.plot(kind='bar')
    plt.xlabel('Class')
    plt.ylabel('Data points per Class')
    plt.title('Distribution of yi in {0}'.format(type_of_data) )
    plt.grid()
    plt.show()

    # ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
    # -(train_class_distribution.values): the minus sign will give us in decreasing order
    sorted_yi = np.argsort(-class_distribution.values)
    for i in sorted_yi:
        print('Number of data points in class', i+1, ':',class_distribution.values[i],
              '(', np.round((class_distribution.values[i]/data_df.shape[0]*100), 3), '%)')
    print('-'*80)

datasetDistributions(train_class_distribution, train_df, 'train data')
datasetDistributions(test_class_distribution, test_df, 'test data')
datasetDistributions(cv_class_distribution, cv_df, 'cv data')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)
# --------------------------------------------------------------------------------

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.441015388850723
# Log loss on Test Data using Random Model 2.4881667721598806
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 236
# BRCA1     187
# TP53       97
# EGFR       85
# PTEN       84
# BRCA2      77
# KIT        64
# BRAF       54
# ERBB2      52
# ALK        40
# PDGFRA     37
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 236 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2898    BRCA2
# 3016      KIT
# 2829    BRCA2
# 2984      KIT
# 2954     GNAS
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1a',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'asxl1',
#  'atm',
#  'atr',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axl',
#  'b2m',
#  'bap1',
#  'bcl10',
#  'bcl2',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brd4',
#  'brip1',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fanca',
#  'fancc',
#  'fat1',
#  'fbxw7',
#  'fgf19',
#  'fgf3',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt1',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'gata3',
#  'gli1',
#  'gnas',
#  'h3f3a',
#  'hist1h1c',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'ikzf1',
#  'il7r',
#  'jak1',
#  'jak2',
#  'jun',
#  'kdm5a',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'klf4',
#  'kmt2a',
#  'kmt2b',
#  'kmt2c',
#  'kmt2d',
#  'knstrn',
#  'kras',
#  'lats1',
#  'lats2',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm4',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'mycn',
#  'myd88',
#  'myod1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'npm1',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pak1',
#  'pax8',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pim1',
#  'pms2',
#  'pole',
#  'ppm1d',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51c',
#  'rad54l',
#  'raf1',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rit1',
#  'ros1',
#  'rras2',
#  'runx1',
#  'rybp',
#  'sdhb',
#  'sdhc',
#  'setd2',
#  'sf3b1',
#  'shq1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'srsf2',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf3',
#  'tcf7l2',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vhl',
#  'whsc1',
#  'whsc1l1',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 235)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3822377936723502
# For values of alpha =  0.0001 The log loss is: 1.1929261950300807
# For values of alpha =  0.001 The log loss is: 1.2120366016605435
# For values of alpha =  0.01 The log loss is: 1.3447863753118887
# For values of alpha =  0.1 The log loss is: 1.4677223299523456
# For values of alpha =  1 The log loss is: 1.5107988189950379
# For values of best alpha =  0.0001 The train log loss is: 1.053828291106648
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1929261950300807
# For values of best alpha =  0.0001 The test log loss is: 1.2106456106863115

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  236  genes in train dataset?
# Ans
# 1. In test data 647 out of 665 : 97.29323308270676
# 2. In cross validation data 516 out of  532 : 96.99248120300751

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 227
# BRCA1            182
# TP53              97
# EGFR              83
# PTEN              82
# BRCA2             75
# KIT               63
# BRAF              54
# Deletion          54
# ERBB2             51
# Amplification     49
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 227 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 227)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3058071063292318
# For values of alpha =  0.0001 The log loss is: 1.1247477498116203
# For values of alpha =  0.001 The log loss is: 1.139583249997119
# For values of alpha =  0.01 The log loss is: 1.264519412455761
# For values of alpha =  0.1 The log loss is: 1.3881415683086071
# For values of alpha =  1 The log loss is: 1.4354908900825383
# For values of best alpha =  0.0001 The train log loss is: 1.0038340577357863
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1247477498116203
# For values of best alpha =  0.0001 The test log loss is: 1.1509375936575552

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  227  genes in test and cross validation data sets?
# Ans
# 1. In test data 645 out of 665 : 96.99248120300751
# 2. In cross validation data 513 out of  532 : 96.42857142857143

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(max_features=1000)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
"""
The below code snippet is preparing onehotCoding with CountVectorizer Unigram
"""
text_vectorizer_unigram = CountVectorizer(min_df=3, ngram_range=(1,1))
train_text_feature_onehotCoding_unigram = text_vectorizer_unigram.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features_unigram= text_vectorizer_unigram.get_feature_names()

# don't forget to normalize every feature
train_text_feature_onehotCoding_unigram = normalize(train_text_feature_onehotCoding_unigram, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_unigram = text_vectorizer_unigram.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_unigram = normalize(test_text_feature_onehotCoding_unigram, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_unigram = text_vectorizer_unigram.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_unigram = normalize(cv_text_feature_onehotCoding_unigram, axis=0)

# %%
"""
The below code snippet is preparing onehotCoding with CountVectorizer Bigram
"""
text_vectorizer_bigram = CountVectorizer(min_df=2, ngram_range=(1,2))
train_text_feature_onehotCoding_bigram = text_vectorizer_bigram.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features_bigram= text_vectorizer_bigram.get_feature_names()

# don't forget to normalize every feature
train_text_feature_onehotCoding_bigram = normalize(train_text_feature_onehotCoding_bigram, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_bigram = text_vectorizer_bigram.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_bigram = normalize(test_text_feature_onehotCoding_bigram, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_bigram = text_vectorizer_bigram.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_bigram = normalize(cv_text_feature_onehotCoding_bigram, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({255.90185533110517: 1, 184.11423761019608: 1, 144.12593765230932: 1, 131.8532650935133: 1, 131.01665041776482: 1, 120.89174703986654: 1, 120.43318106197158: 1, 115.51497668249378: 1, 110.43501365301566: 1, 107.86765322655576: 1, 107.68293683352165: 1, 90.5569281242001: 1, 89.15963521996571: 1, 85.17852579893803: 1, 81.77361945175716: 1, 79.69828202118367: 1, 79.65361216887604: 1, 79.15783483939843: 1, 78.03301499407614: 1, 77.98252798805119: 1, 77.88301341664948: 1, 75.83988013380798: 1, 70.97082329734825: 1, 70.75418591120535: 1, 68.23020011478106: 1, 66.35479488005797: 1, 66.21672705852855: 1, 65.00552691206846: 1, 64.77061269134052: 1, 64.71030192981046: 1, 64.56495509887884: 1, 64.179864531345: 1, 62.570030875211714: 1, 60.16462776079511: 1, 60.016510729285805: 1, 59.48675526511261: 1, 57.37620667607828: 1, 55.76715060850032: 1, 55.22088484990045: 1, 50.32769544339813: 1, 49.883864950754294: 1, 49.38393880174753: 1, 48.945433087105066: 1, 48.76641011379554: 1, 47.9625089679041: 1, 46.309015245184774: 1, 46.24931791804596: 1, 46.24747274335289: 1, 46.089575890823845: 1, 45.952841177097554: 1, 44.7534373499109: 1, 43.91027441440458: 1, 43.81786023619336: 1, 43.814538398626006: 1, 43.75532137469009: 1, 43.3065209488803: 1, 42.518575539237325: 1, 42.35508331241753: 1, 42.31181368971988: 1, 42.30519917562794: 1, 42.28160211317159: 1, 42.21995098330475: 1, 41.922088391880585: 1, 41.34607505137677: 1, 40.97600231256184: 1, 40.07850114848076: 1, 39.89160193601111: 1, 39.83843804780032: 1, 39.56570992021487: 1, 38.982435149230476: 1, 38.747401305656766: 1, 38.57932662473109: 1, 37.90404060222844: 1, 36.979995193195016: 1, 36.97522108881037: 1, 36.94076379139515: 1, 36.93662675708388: 1, 36.44839440590421: 1, 36.15739603545344: 1, 36.09626517316542: 1, 35.84151135468977: 1, 35.68065202374449: 1, 35.290724355462814: 1, 35.258376259212156: 1, 34.936648793525755: 1, 34.36972530791075: 1, 34.13483808277068: 1, 33.59862395183332: 1, 33.43356994612539: 1, 33.31138561910525: 1, 33.29944799665086: 1, 33.29831113285992: 1, 33.189449242294636: 1, 32.87377610962708: 1, 32.72677604571634: 1, 32.33375697733582: 1, 32.32461906920712: 1, 32.24928350769615: 1, 32.24171185127089: 1, 32.098822389803324: 1, 32.046692411328586: 1, 32.02921356365859: 1, 31.938886471496307: 1, 31.859685814449247: 1, 31.820907057825845: 1, 31.446754478366895: 1, 31.426214708775248: 1, 31.405725215275442: 1, 31.378803022420428: 1, 31.371937470091183: 1, 31.0503954686784: 1, 31.02488740288271: 1, 30.98659045236893: 1, 30.922662207776582: 1, 30.856825004450904: 1, 30.534773096383358: 1, 30.50775631001144: 1, 30.455690928586783: 1, 30.249140123738727: 1, 30.193850384208083: 1, 30.078502704809665: 1, 29.962498863646793: 1, 29.782310389278702: 1, 29.771540079278225: 1, 29.34950591010072: 1, 29.10436217824939: 1, 29.040030458032717: 1, 28.66961705896328: 1, 28.469915488137854: 1, 28.378741993525164: 1, 28.034354516685426: 1, 28.01331307338398: 1, 27.92851408483568: 1, 27.92656725254865: 1, 27.836888963078476: 1, 27.787181927290305: 1, 27.76273055518005: 1, 27.518544006442617: 1, 27.451855015675136: 1, 27.423081900034013: 1, 27.058477517626073: 1, 26.889400909319924: 1, 26.750195495870035: 1, 26.697191979607805: 1, 26.574430901207016: 1, 26.503312146091176: 1, 26.04218733466793: 1, 25.916657418971422: 1, 25.913035147796244: 1, 25.792178702463264: 1, 25.79134640010361: 1, 25.7630693672534: 1, 25.603593270164744: 1, 25.602800139229803: 1, 25.475584112147285: 1, 25.263985350959928: 1, 25.223355850458624: 1, 25.22232606849897: 1, 25.15060050053125: 1, 24.845739971109932: 1, 24.747418418211424: 1, 24.739480225408762: 1, 24.729712902575454: 1, 24.48408549823498: 1, 24.424249197448386: 1, 24.326461025264155: 1, 24.300727979323394: 1, 24.248986513364095: 1, 24.24469878106787: 1, 24.220229676409392: 1, 24.164024827062498: 1, 24.110026201444285: 1, 24.103859928155657: 1, 24.09225234433855: 1, 24.08403648203988: 1, 24.080477160098113: 1, 24.028803994117183: 1, 23.98650284514161: 1, ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.0357407516708133
# For values of alpha =  0.0001 The log loss is: 1.0664872033341035
# For values of alpha =  0.001 The log loss is: 1.356914044284584
# For values of alpha =  0.01 The log loss is: 1.9709164235591183
# For values of alpha =  0.1 The log loss is: 2.0691496144571326
# For values of alpha =  1 The log loss is: 2.0487882845292202
# For values of best alpha =  1e-05 The train log loss is: 0.7918277540079143
# For values of best alpha =  1e-05 The cross validation log loss is: 1.0357407516708133
# For values of best alpha =  1e-05 The test log loss is: 1.0809619517272626

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(max_features=1000)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 94.5 % of word of test data appeared in train data
# 94.4 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = TfidfVectorizer(max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))


# Stack Onehot coding for TF IDF vestorizers
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()

# Stack Onehot coding for Countvestorizer Unigram

train_x_onehotCoding_unigram = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding_unigram)).tocsr()
test_x_onehotCoding_unigram = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding_unigram)).tocsr()
cv_x_onehotCoding_unigram = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding_unigram)).tocsr()

# Stack Onehot coding for Countvestorizer Bigram

train_x_onehotCoding_bigram = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding_bigram)).tocsr()
test_x_onehotCoding_bigram = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding_bigram)).tocsr()
cv_x_onehotCoding_bigram = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding_bigram)).tocsr()


# Spliting class labels into diffrent variables
train_y = np.array(list(train_df['Class']))
test_y = np.array(list(test_df['Class']))
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 1462)
# (number of data points * number of features) in test data =  (665, 1462)
# (number of data points * number of features) in cross validation data = (532, 1462)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1871224350882748
# for alpha = 0.0001
# Log Loss : 1.1876363861190142
# for alpha = 0.001
# Log Loss : 1.1874573534375974
# for alpha = 0.1
# Log Loss : 1.1712840460636393
# for alpha = 1
# Log Loss : 1.154706166839247
# for alpha = 10
# Log Loss : 1.1931076489736487
# for alpha = 100
# Log Loss : 1.2938387201989394
# for alpha = 1000
# Log Loss : 1.3109846949557067
# For values of best alpha =  1 The train log loss is: 1.0649417092699107
# For values of best alpha =  1 The cross validation log loss is: 1.154706166839247
# For values of best alpha =  1 The test log loss is: 1.194296278184462

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.154706166839247
# Number of missclassified point : 0.37030075187969924
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print(indices)
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0511 0.6775 0.0184 0.0548 0.0357 0.043  0.1093 0.0039 0.0061]]
# Actual Class : 5
# [[ 115  345   61  288  316    0  244  237  254   27  293   66  194  164
#    420  385  208  190  100  433  150  373  416 1140  676 1410 1249 1386
#    311  125   65  351   87  292 1350 1385  468 1064  467 1067  474  469
#   1034  762 1349 1186  935  905 1039  475  580  957  844  913  465  594
#   1080 1409 1236 1390  977 1119  471  754 1211  677 1248  998  921  875
#    568 1123  482  954   86   76    6  163  384  473  769 1371  688 1078
#    592 1100 1388 1139 1180 1305 1431 1411 1250 1134  855  691  927 1112
#    753 1414]]
# --------------------------------------------------
# 23 Text feature [patients] present in test data point [True]
# 24 Text feature [clinical] present in test data point [True]
# 25 Text feature [treatment] present in test data point [True]
# 26 Text feature [response] present in test data point [True]
# 27 Text feature [therapy] present in test data point [True]
# 34 Text feature [study] present in test data point [True]
# 35 Text feature [therapeutic] present in test data point [True]
# 36 Text feature [12] present in test data point [True]
# 37 Text feature [molecular] present in test data point [True]
# 38 Text feature [11] present in test data point [True]
# 40 Text feature [18] present in test data point [True]
# 41 Text feature [13] present in test data point [True]
# 42 Text feature [may] present in test data point [True]
# 43 Text feature [different] present in test data point [True]
# 44 Text feature [studies] present in test data point [True]
# 46 Text feature [including] present in test data point [True]
# 47 Text feature [higher] present in test data point [True]
# 49 Text feature [19] present in test data point [True]
# 50 Text feature [also] present in test data point [True]
# 51 Text feature [initial] present in test data point [True]
# 52 Text feature [first] present in test data point [True]
# 53 Text feature [however] present in test data point [True]
# 54 Text feature [10] present in test data point [True]
# 55 Text feature [another] present in test data point [True]
# 56 Text feature [mutations] present in test data point [True]
# 57 Text feature [treated] present in test data point [True]
# 58 Text feature [reported] present in test data point [True]
# 59 Text feature [time] present in test data point [True]
# 60 Text feature [kinase] present in test data point [True]
# 61 Text feature [one] present in test data point [True]
# 62 Text feature [15] present in test data point [True]
# 64 Text feature [recently] present in test data point [True]
# 66 Text feature [respectively] present in test data point [True]
# 67 Text feature [less] present in test data point [True]
# 68 Text feature [identified] present in test data point [True]
# 69 Text feature [gene] present in test data point [True]
# 70 Text feature [advanced] present in test data point [True]
# 72 Text feature [20] present in test data point [True]
# 73 Text feature [inhibitor] present in test data point [True]
# 79 Text feature [17] present in test data point [True]
# 80 Text feature [disease] present in test data point [True]
# 81 Text feature [table] present in test data point [True]
# 82 Text feature [common] present in test data point [True]
# 83 Text feature [mutation] present in test data point [True]
# 84 Text feature [analysis] present in test data point [True]
# 85 Text feature [novel] present in test data point [True]
# 86 Text feature [three] present in test data point [True]
# 87 Text feature [patient] present in test data point [True]
# 88 Text feature [primary] present in test data point [True]
# 89 Text feature [similar] present in test data point [True]
# 90 Text feature [using] present in test data point [True]
# 92 Text feature [responses] present in test data point [True]
# 94 Text feature [found] present in test data point [True]
# 97 Text feature [observed] present in test data point [True]
# 98 Text feature [detected] present in test data point [True]
# 99 Text feature [tumor] present in test data point [True]
# Out of the top  100  features  56 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0602 0.2687 0.0208 0.0638 0.0416 0.0604 0.4734 0.0042 0.0071]]
# Actual Class : 7
# --------------------------------------------------
# 28 Text feature [activation] present in test data point [True]
# 29 Text feature [kinase] present in test data point [True]
# 30 Text feature [activated] present in test data point [True]
# 31 Text feature [downstream] present in test data point [True]
# 34 Text feature [cells] present in test data point [True]
# 35 Text feature [inhibitor] present in test data point [True]
# 36 Text feature [sensitive] present in test data point [True]
# 37 Text feature [signaling] present in test data point [True]
# 38 Text feature [independent] present in test data point [True]
# 40 Text feature [expressing] present in test data point [True]
# 41 Text feature [growth] present in test data point [True]
# 42 Text feature [10] present in test data point [True]
# 45 Text feature [also] present in test data point [True]
# 46 Text feature [treatment] present in test data point [True]
# 47 Text feature [however] present in test data point [True]
# 49 Text feature [well] present in test data point [True]
# 50 Text feature [shown] present in test data point [True]
# 51 Text feature [inhibition] present in test data point [True]
# 52 Text feature [addition] present in test data point [True]
# 53 Text feature [activating] present in test data point [True]
# 54 Text feature [compared] present in test data point [True]
# 55 Text feature [inhibitors] present in test data point [True]
# 56 Text feature [similar] present in test data point [True]
# 57 Text feature [cell] present in test data point [True]
# 58 Text feature [mutations] present in test data point [True]
# 59 Text feature [factor] present in test data point [True]
# 60 Text feature [higher] present in test data point [True]
# 61 Text feature [presence] present in test data point [True]
# 64 Text feature [potential] present in test data point [True]
# 65 Text feature [treated] present in test data point [True]
# 66 Text feature [previously] present in test data point [True]
# 67 Text feature [without] present in test data point [True]
# 68 Text feature [may] present in test data point [True]
# 69 Text feature [found] present in test data point [True]
# 70 Text feature [3b] present in test data point [True]
# 71 Text feature [phosphorylation] present in test data point [True]
# 78 Text feature [oncogenic] present in test data point [True]
# 81 Text feature [mutation] present in test data point [True]
# 82 Text feature [20] present in test data point [True]
# 83 Text feature [reported] present in test data point [True]
# 84 Text feature [increased] present in test data point [True]
# 85 Text feature [respectively] present in test data point [True]
# 87 Text feature [3a] present in test data point [True]
# 89 Text feature [receptor] present in test data point [True]
# 90 Text feature [studies] present in test data point [True]
# 91 Text feature [12] present in test data point [True]
# 92 Text feature [although] present in test data point [True]
# 93 Text feature [expressed] present in test data point [True]
# 94 Text feature [different] present in test data point [True]
# 95 Text feature [tyrosine] present in test data point [True]
# 96 Text feature [total] present in test data point [True]
# 97 Text feature [two] present in test data point [True]
# 98 Text feature [results] present in test data point [True]
# Out of the top  100  features  53 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.0144682140921921
# for alpha = 11
# Log Loss : 1.0113182436132029
# for alpha = 15
# Log Loss : 1.024357149590547
# for alpha = 21
# Log Loss : 1.0370022350325572
# for alpha = 31
# Log Loss : 1.039189457351096
# for alpha = 41
# Log Loss : 1.052722140122109
# for alpha = 51
# Log Loss : 1.062117293591942
# for alpha = 99
# Log Loss : 1.0773838179344084
# For values of best alpha =  11 The train log loss is: 0.8041548895670346
# For values of best alpha =  11 The cross validation log loss is: 1.0113182436132029
# For values of best alpha =  11 The test log loss is: 1.0455247734439765

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0113182436132029
# Number of mis-classified points : 0.33458646616541354
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 2
# Actual Class : 5
# The  11  nearest neighbours of the test points belongs to classes [7 2 2 2 2 2 2 7 2 2 2]
# Fequency of nearest points : Counter({2: 9, 7: 2})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [2 7 7 7 2 7 2 7 7 7 7]
# Fequency of nearest points : Counter({7: 8, 2: 3})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning with TF IDF</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1740392582626333
# for alpha = 1e-05
# Log Loss : 1.1317633281451804
# for alpha = 0.0001
# Log Loss : 0.9493138756199783
# for alpha = 0.001
# Log Loss : 0.9650519917620252
# for alpha = 0.01
# Log Loss : 1.1434662138117837
# for alpha = 0.1
# Log Loss : 1.501064146339378
# for alpha = 1
# Log Loss : 1.6596385859130143
# for alpha = 10
# Log Loss : 1.6840285390472052
# for alpha = 100
# Log Loss : 1.6870721751266544
# For values of best alpha =  0.0001 The train log loss is: 0.8066459406708673
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9493138756199783
# For values of best alpha =  0.0001 The test log loss is: 0.9864112986185856

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9493138756199783
# Number of mis-classified points : 0.3157894736842105
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],
                     test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0209 0.3757 0.0069 0.0405 0.0384 0.0493 0.4492 0.0091 0.01  ]]
# Actual Class : 5
# --------------------------------------------------
# 1 Text feature [downstream] present in test data point [True]
# 8 Text feature [activation] present in test data point [True]
# 19 Text feature [constitutive] present in test data point [True]
# 24 Text feature [overexpression] present in test data point [True]
# 33 Text feature [positive] present in test data point [True]
# 38 Text feature [14] present in test data point [True]
# 41 Text feature [observations] present in test data point [True]
# 51 Text feature [advanced] present in test data point [True]
# 53 Text feature [versus] present in test data point [True]
# 55 Text feature [enhanced] present in test data point [True]
# 58 Text feature [signaling] present in test data point [True]
# 68 Text feature [3b] present in test data point [True]
# 70 Text feature [without] present in test data point [True]
# 74 Text feature [sensitive] present in test data point [True]
# 75 Text feature [coding] present in test data point [True]
# 76 Text feature [approximately] present in test data point [True]
# 79 Text feature [inhibited] present in test data point [True]
# 80 Text feature [activated] present in test data point [True]
# 85 Text feature [leading] present in test data point [True]
# 87 Text feature [days] present in test data point [True]
# 88 Text feature [occur] present in test data point [True]
# 91 Text feature [examined] present in test data point [True]
# 98 Text feature [open] present in test data point [True]
# 99 Text feature [properties] present in test data point [True]
# 103 Text feature [phospho] present in test data point [True]
# 108 Text feature [concentrations] present in test data point [True]
# 109 Text feature [distinct] present in test data point [True]
# 110 Text feature [elevated] present in test data point [True]
# 116 Text feature [phosphorylated] present in test data point [True]
# 118 Text feature [pathways] present in test data point [True]
# 119 Text feature [2b] present in test data point [True]
# 120 Text feature [factor] present in test data point [True]
# 135 Text feature [provided] present in test data point [True]
# 140 Text feature [2a] present in test data point [True]
# 144 Text feature [additional] present in test data point [True]
# 145 Text feature [25] present in test data point [True]
# 156 Text feature [32] present in test data point [True]
# 158 Text feature [increase] present in test data point [True]
# 160 Text feature [wt] present in test data point [True]
# 162 Text feature [reverse] present in test data point [True]
# 165 Text feature [cancers] present in test data point [True]
# 168 Text feature [interestingly] present in test data point [True]
# 170 Text feature [manner] present in test data point [True]
# 172 Text feature [3a] present in test data point [True]
# 179 Text feature [genomic] present in test data point [True]
# 181 Text feature [inhibitor] present in test data point [True]
# 184 Text feature [lead] present in test data point [True]
# 186 Text feature [s3] present in test data point [True]
# 188 Text feature [extracellular] present in test data point [True]
# 192 Text feature [presence] present in test data point [True]
# 193 Text feature [regions] present in test data point [True]
# 194 Text feature [mechanisms] present in test data point [True]
# 196 Text feature [fig] present in test data point [True]
# 201 Text feature [24] present in test data point [True]
# 202 Text feature [72] present in test data point [True]
# 203 Text feature [fold] present in test data point [True]
# 204 Text feature [contribute] present in test data point [True]
# 208 Text feature [position] present in test data point [True]
# 209 Text feature [tumors] present in test data point [True]
# 210 Text feature [50] present in test data point [True]
# 215 Text feature [ligand] present in test data point [True]
# 216 Text feature [oncogenic] present in test data point [True]
# 219 Text feature [mm] present in test data point [True]
# 221 Text feature [previously] present in test data point [True]
# 225 Text feature [hours] present in test data point [True]
# 226 Text feature [28] present in test data point [True]
# 227 Text feature [driven] present in test data point [True]
# 229 Text feature [cyclin] present in test data point [True]
# 231 Text feature [29] present in test data point [True]
# 232 Text feature [44] present in test data point [True]
# 233 Text feature [liver] present in test data point [True]
# 241 Text feature [37] present in test data point [True]
# 242 Text feature [negative] present in test data point [True]
# 248 Text feature [materials] present in test data point [True]
# 249 Text feature [effective] present in test data point [True]
# 250 Text feature [org] present in test data point [True]
# 254 Text feature [primers] present in test data point [True]
# 255 Text feature [various] present in test data point [True]
# 256 Text feature [ca] present in test data point [True]
# 258 Text feature [mutated] present in test data point [True]
# 259 Text feature [cdk4] present in test data point [True]
# 260 Text feature [nucleotide] present in test data point [True]
# 266 Text feature [gfp] present in test data point [True]
# 267 Text feature [substitution] present in test data point [True]
# 268 Text feature [carcinoma] present in test data point [True]
# 269 Text feature [could] present in test data point [True]
# 271 Text feature [recently] present in test data point [True]
# 279 Text feature [years] present in test data point [True]
# 280 Text feature [specific] present in test data point [True]
# 284 Text feature [level] present in test data point [True]
# 285 Text feature [resistant] present in test data point [True]
# 287 Text feature [mutants] present in test data point [True]
# 288 Text feature [2000] present in test data point [True]
# 289 Text feature [independent] present in test data point [True]
# 290 Text feature [absence] present in test data point [True]
# 292 Text feature [activating] present in test data point [True]
# 293 Text feature [suggest] present in test data point [True]
# 294 Text feature [increased] present in test data point [True]
# 296 Text feature [corresponding] present in test data point [True]
# 297 Text feature [high] present in test data point [True]
# 298 Text feature [green] present in test data point [True]
# 301 Text feature [furthermore] present in test data point [True]
# 302 Text feature [total] present in test data point [True]
# 303 Text feature [akt] present in test data point [True]
# 304 Text feature [41] present in test data point [True]
# 305 Text feature [established] present in test data point [True]
# 306 Text feature [000] present in test data point [True]
# 307 Text feature [form] present in test data point [True]
# 309 Text feature [survival] present in test data point [True]
# 310 Text feature [plasma] present in test data point [True]
# 313 Text feature [supplementary] present in test data point [True]
# 314 Text feature [10] present in test data point [True]
# 315 Text feature [mediated] present in test data point [True]
# 317 Text feature [inhibition] present in test data point [True]
# 318 Text feature [plates] present in test data point [True]
# 320 Text feature [mutant] present in test data point [True]
# 329 Text feature [report] present in test data point [True]
# 330 Text feature [sites] present in test data point [True]
# 331 Text feature [model] present in test data point [True]
# 332 Text feature [standard] present in test data point [True]
# 333 Text feature [22] present in test data point [True]
# 339 Text feature [d1] present in test data point [True]
# 341 Text feature [phosphorylation] present in test data point [True]
# 342 Text feature [localization] present in test data point [True]
# 343 Text feature [12] present in test data point [True]
# 344 Text feature [constitutively] present in test data point [True]
# 349 Text feature [include] present in test data point [True]
# 350 Text feature [initial] present in test data point [True]
# 351 Text feature [35] present in test data point [True]
# 353 Text feature [might] present in test data point [True]
# 355 Text feature [malignant] present in test data point [True]
# 357 Text feature [resulting] present in test data point [True]
# 360 Text feature [factors] present in test data point [True]
# 364 Text feature [per] present in test data point [True]
# 365 Text feature [transcription] present in test data point [True]
# 367 Text feature [mechanism] present in test data point [True]
# 369 Text feature [consistent] present in test data point [True]
# 372 Text feature [see] present in test data point [True]
# 374 Text feature [generated] present in test data point [True]
# 379 Text feature [nuclear] present in test data point [True]
# 380 Text feature [incubated] present in test data point [True]
# 382 Text feature [pathway] present in test data point [True]
# 386 Text feature [cells] present in test data point [True]
# 388 Text feature [led] present in test data point [True]
# 389 Text feature [published] present in test data point [True]
# 391 Text feature [chromosome] present in test data point [True]
# 392 Text feature [dependent] present in test data point [True]
# 394 Text feature [note] present in test data point [True]
# 397 Text feature [treatment] present in test data point [True]
# 401 Text feature [70] present in test data point [True]
# 404 Text feature [well] present in test data point [True]
# 405 Text feature [mice] present in test data point [True]
# 407 Text feature [time] present in test data point [True]
# 409 Text feature [obtained] present in test data point [True]
# 411 Text feature [fact] present in test data point [True]
# 412 Text feature [tissue] present in test data point [True]
# 414 Text feature [lines] present in test data point [True]
# 416 Text feature [respectively] present in test data point [True]
# 417 Text feature [18] present in test data point [True]
# 419 Text feature [among] present in test data point [True]
# 423 Text feature [either] present in test data point [True]
# 429 Text feature [tumor] present in test data point [True]
# 431 Text feature [regulation] present in test data point [True]
# 432 Text feature [kinase] present in test data point [True]
# 433 Text feature [two] present in test data point [True]
# 434 Text feature [expressed] present in test data point [True]
# 438 Text feature [cycle] present in test data point [True]
# 439 Text feature [limited] present in test data point [True]
# 440 Text feature [use] present in test data point [True]
# 441 Text feature [growth] present in test data point [True]
# 442 Text feature [16] present in test data point [True]
# 443 Text feature [concentration] present in test data point [True]
# 445 Text feature [induction] present in test data point [True]
# 446 Text feature [therapy] present in test data point [True]
# 449 Text feature [also] present in test data point [True]
# 451 Text feature [common] present in test data point [True]
# 453 Text feature [signal] present in test data point [True]
# 454 Text feature [available] present in test data point [True]
# 455 Text feature [constructs] present in test data point [True]
# 457 Text feature [found] present in test data point [True]
# 458 Text feature [mouse] present in test data point [True]
# 460 Text feature [higher] present in test data point [True]
# 461 Text feature [determine] present in test data point [True]
# 462 Text feature [free] present in test data point [True]
# 463 Text feature [region] present in test data point [True]
# 466 Text feature [promote] present in test data point [True]
# 467 Text feature [addition] present in test data point [True]
# 468 Text feature [exhibited] present in test data point [True]
# 470 Text feature [whereas] present in test data point [True]
# 471 Text feature [general] present in test data point [True]
# 474 Text feature [showed] present in test data point [True]
# 475 Text feature [part] present in test data point [True]
# 476 Text feature [american] present in test data point [True]
# 477 Text feature [reported] present in test data point [True]
# 478 Text feature [association] present in test data point [True]
# 479 Text feature [another] present in test data point [True]
# 480 Text feature [sequenced] present in test data point [True]
# 482 Text feature [multiple] present in test data point [True]
# 483 Text feature [conditions] present in test data point [True]
# 485 Text feature [57] present in test data point [True]
# 487 Text feature [targeting] present in test data point [True]
# 489 Text feature [within] present in test data point [True]
# 491 Text feature [inhibitory] present in test data point [True]
# 494 Text feature [molecular] present in test data point [True]
# 495 Text feature [alternative] present in test data point [True]
# 496 Text feature [disease] present in test data point [True]
# 498 Text feature [recent] present in test data point [True]
# 499 Text feature [prior] present in test data point [True]
# Out of the top  500  features  208 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0188 0.2132 0.0202 0.0116 0.0281 0.097  0.606  0.0029 0.0023]]
# Actual Class : 7
# --------------------------------------------------
# 1 Text feature [downstream] present in test data point [True]
# 2 Text feature [insertion] present in test data point [True]
# 8 Text feature [activation] present in test data point [True]
# 12 Text feature [colony] present in test data point [True]
# 20 Text feature [transformed] present in test data point [True]
# 24 Text feature [overexpression] present in test data point [True]
# 33 Text feature [positive] present in test data point [True]
# 38 Text feature [14] present in test data point [True]
# 43 Text feature [ras] present in test data point [True]
# 54 Text feature [61] present in test data point [True]
# 58 Text feature [signaling] present in test data point [True]
# 68 Text feature [3b] present in test data point [True]
# 70 Text feature [without] present in test data point [True]
# 74 Text feature [sensitive] present in test data point [True]
# 79 Text feature [inhibited] present in test data point [True]
# 80 Text feature [activated] present in test data point [True]
# 90 Text feature [leukemia] present in test data point [True]
# 91 Text feature [examined] present in test data point [True]
# 92 Text feature [fusion] present in test data point [True]
# 99 Text feature [properties] present in test data point [True]
# 105 Text feature [chromosomal] present in test data point [True]
# 108 Text feature [concentrations] present in test data point [True]
# 109 Text feature [distinct] present in test data point [True]
# 110 Text feature [elevated] present in test data point [True]
# 111 Text feature [blood] present in test data point [True]
# 115 Text feature [braf] present in test data point [True]
# 116 Text feature [phosphorylated] present in test data point [True]
# 118 Text feature [pathways] present in test data point [True]
# 120 Text feature [factor] present in test data point [True]
# 135 Text feature [provided] present in test data point [True]
# 137 Text feature [frame] present in test data point [True]
# 141 Text feature [activate] present in test data point [True]
# 144 Text feature [additional] present in test data point [True]
# 145 Text feature [25] present in test data point [True]
# 156 Text feature [32] present in test data point [True]
# 157 Text feature [frequent] present in test data point [True]
# 162 Text feature [reverse] present in test data point [True]
# 171 Text feature [features] present in test data point [True]
# 172 Text feature [3a] present in test data point [True]
# 173 Text feature [mapk] present in test data point [True]
# 179 Text feature [genomic] present in test data point [True]
# 181 Text feature [inhibitor] present in test data point [True]
# 186 Text feature [s3] present in test data point [True]
# 192 Text feature [presence] present in test data point [True]
# 196 Text feature [fig] present in test data point [True]
# 201 Text feature [24] present in test data point [True]
# 202 Text feature [72] present in test data point [True]
# 205 Text feature [transforming] present in test data point [True]
# 210 Text feature [50] present in test data point [True]
# 215 Text feature [ligand] present in test data point [True]
# 216 Text feature [oncogenic] present in test data point [True]
# 221 Text feature [previously] present in test data point [True]
# 223 Text feature [jak2] present in test data point [True]
# 226 Text feature [28] present in test data point [True]
# 241 Text feature [37] present in test data point [True]
# 242 Text feature [negative] present in test data point [True]
# 249 Text feature [effective] present in test data point [True]
# 250 Text feature [org] present in test data point [True]
# 260 Text feature [nucleotide] present in test data point [True]
# 265 Text feature [43] present in test data point [True]
# 277 Text feature [nf1] present in test data point [True]
# 279 Text feature [years] present in test data point [True]
# 289 Text feature [independent] present in test data point [True]
# 292 Text feature [activating] present in test data point [True]
# 294 Text feature [increased] present in test data point [True]
# 295 Text feature [end] present in test data point [True]
# 297 Text feature [high] present in test data point [True]
# 301 Text feature [furthermore] present in test data point [True]
# 302 Text feature [total] present in test data point [True]
# 304 Text feature [41] present in test data point [True]
# 305 Text feature [established] present in test data point [True]
# 306 Text feature [000] present in test data point [True]
# 308 Text feature [seen] present in test data point [True]
# 309 Text feature [survival] present in test data point [True]
# 311 Text feature [current] present in test data point [True]
# 312 Text feature [characteristics] present in test data point [True]
# 313 Text feature [supplementary] present in test data point [True]
# 314 Text feature [10] present in test data point [True]
# 317 Text feature [inhibition] present in test data point [True]
# 323 Text feature [49] present in test data point [True]
# 324 Text feature [expressing] present in test data point [True]
# 331 Text feature [model] present in test data point [True]
# 332 Text feature [standard] present in test data point [True]
# 333 Text feature [22] present in test data point [True]
# 338 Text feature [nm] present in test data point [True]
# 341 Text feature [phosphorylation] present in test data point [True]
# 343 Text feature [12] present in test data point [True]
# 347 Text feature [deletion] present in test data point [True]
# 351 Text feature [35] present in test data point [True]
# 354 Text feature [ph] present in test data point [True]
# 355 Text feature [malignant] present in test data point [True]
# 357 Text feature [resulting] present in test data point [True]
# 358 Text feature [suppression] present in test data point [True]
# 360 Text feature [factors] present in test data point [True]
# 364 Text feature [per] present in test data point [True]
# 365 Text feature [transcription] present in test data point [True]
# 369 Text feature [consistent] present in test data point [True]
# 373 Text feature [strong] present in test data point [True]
# 382 Text feature [pathway] present in test data point [True]
# 383 Text feature [kras] present in test data point [True]
# 386 Text feature [cells] present in test data point [True]
# 387 Text feature [fusions] present in test data point [True]
# 391 Text feature [chromosome] present in test data point [True]
# 392 Text feature [dependent] present in test data point [True]
# 397 Text feature [treatment] present in test data point [True]
# 398 Text feature [associated] present in test data point [True]
# 404 Text feature [well] present in test data point [True]
# 405 Text feature [mice] present in test data point [True]
# 409 Text feature [obtained] present in test data point [True]
# 414 Text feature [lines] present in test data point [True]
# 415 Text feature [indicate] present in test data point [True]
# 416 Text feature [respectively] present in test data point [True]
# 417 Text feature [18] present in test data point [True]
# 419 Text feature [among] present in test data point [True]
# 420 Text feature [lesions] present in test data point [True]
# 423 Text feature [either] present in test data point [True]
# 429 Text feature [tumor] present in test data point [True]
# 431 Text feature [regulation] present in test data point [True]
# 432 Text feature [kinase] present in test data point [True]
# 433 Text feature [two] present in test data point [True]
# 434 Text feature [expressed] present in test data point [True]
# 436 Text feature [flt3] present in test data point [True]
# 437 Text feature [ba] present in test data point [True]
# 439 Text feature [limited] present in test data point [True]
# 440 Text feature [use] present in test data point [True]
# 441 Text feature [growth] present in test data point [True]
# 442 Text feature [16] present in test data point [True]
# 443 Text feature [concentration] present in test data point [True]
# 444 Text feature [59] present in test data point [True]
# 445 Text feature [induction] present in test data point [True]
# 446 Text feature [therapy] present in test data point [True]
# 447 Text feature [diagnosis] present in test data point [True]
# 449 Text feature [also] present in test data point [True]
# 451 Text feature [common] present in test data point [True]
# 452 Text feature [f3] present in test data point [True]
# 454 Text feature [available] present in test data point [True]
# 457 Text feature [found] present in test data point [True]
# 458 Text feature [mouse] present in test data point [True]
# 460 Text feature [higher] present in test data point [True]
# 461 Text feature [determine] present in test data point [True]
# 462 Text feature [free] present in test data point [True]
# 465 Text feature [recurrent] present in test data point [True]
# 467 Text feature [addition] present in test data point [True]
# 470 Text feature [whereas] present in test data point [True]
# 476 Text feature [american] present in test data point [True]
# 477 Text feature [reported] present in test data point [True]
# 482 Text feature [multiple] present in test data point [True]
# 484 Text feature [tyrosine] present in test data point [True]
# 486 Text feature [non] present in test data point [True]
# 487 Text feature [targeting] present in test data point [True]
# 491 Text feature [inhibitory] present in test data point [True]
# 494 Text feature [molecular] present in test data point [True]
# 496 Text feature [disease] present in test data point [True]
# 498 Text feature [recent] present in test data point [True]
# Out of the top  500  features  154 are present in query point

# %% [markdown]
# ### Logistic regression with CountVectorizer(Unigram)

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_unigram, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_unigram, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_unigram)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_unigram, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_unigram, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_unigram)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_unigram)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_unigram)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.4063014270341556
# for alpha = 1e-05
# Log Loss : 1.4281912381057729
# for alpha = 0.0001
# Log Loss : 1.3525981990340628
# for alpha = 0.001
# Log Loss : 1.1077418788872908
# for alpha = 0.01
# Log Loss : 1.0970110196611667
# for alpha = 0.1
# Log Loss : 1.3815703829265868
# for alpha = 1
# Log Loss : 1.6168846810091588
# for alpha = 10
# Log Loss : 1.6531620888286738
# for alpha = 100
# Log Loss : 1.657142058848106
# For values of best alpha =  0.01 The train log loss is: 0.7886925173686106
# For values of best alpha =  0.01 The cross validation log loss is: 1.0970110196611667
# For values of best alpha =  0.01 The test log loss is: 1.0964451496612302

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_unigram, train_y, cv_x_onehotCoding_unigram, cv_y, clf)
# Out:
# Log loss : 1.0970110196611667
# Number of mis-classified points : 0.33270676691729323
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
def get_impfeature_names_unigram(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
# from tabulate import tabulate
sig_clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
sig_clf.fit(train_x_onehotCoding_unigram,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_unigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_unigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-sig_clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_unigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index], test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.1037 0.2401 0.06   0.1076 0.0751 0.1038 0.2173 0.0441 0.0482]]
# Actual Class : 5
# --------------------------------------------------
# 165 Text feature [recurred] present in test data point [True]
# 237 Text feature [suboptimal] present in test data point [True]
# 319 Text feature [d473h] present in test data point [True]
# 386 Text feature [therapeutically] present in test data point [True]
# 474 Text feature [tm6] present in test data point [True]
# 478 Text feature [amplifications] present in test data point [True]
# Out of the top  500  features  6 are present in query point

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_unigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_unigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_unigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.1045 0.1944 0.0806 0.0948 0.089  0.0945 0.1919 0.0772 0.0731]]
# Actual Class : 7
# --------------------------------------------------
# 50 Text feature [fusions] present in test data point [True]
# 166 Text feature [rearrangements] present in test data point [True]
# 176 Text feature [uncommon] present in test data point [True]
# 451 Text feature [erg] present in test data point [True]
# 476 Text feature [abl] present in test data point [True]
# Out of the top  500  features  5 are present in query point

# %% [markdown]
# ### Logistic regression with CountVectorizer(Bigram)

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_bigram, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_bigram, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_bigram)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_bigram, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_bigram, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_bigram)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_bigram)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_bigram)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.6083679627883392
# for alpha = 1e-05
# Log Loss : 1.6085386451261965
# for alpha = 0.0001
# Log Loss : 1.6079688092526547
# for alpha = 0.001
# Log Loss : 1.5561014235931239
# for alpha = 0.01
# Log Loss : 1.2234644022918149
# for alpha = 0.1
# Log Loss : 1.1922164694313986
# for alpha = 1
# Log Loss : 1.231133711779909
# for alpha = 10
# Log Loss : 1.293936611894191
# for alpha = 100
# Log Loss : 1.309791680577689
# For values of best alpha =  0.1 The train log loss is: 0.7897877180178343
# For values of best alpha =  0.1 The cross validation log loss is: 1.1922164694313986
# For values of best alpha =  0.1 The test log loss is: 1.208659776436054

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_bigram, train_y, cv_x_onehotCoding_bigram, cv_y, clf)
# Out:
# Log loss : 1.1922164694313986
# Number of mis-classified points : 0.3890977443609023
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
def get_impfeature_names_bigram(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=2, ngram_range=(1,2))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
# from tabulate import tabulate
sig_clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
sig_clf.fit(train_x_onehotCoding_bigram,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-sig_clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_bigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],
                     test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1135 0.1477 0.0898 0.1163 0.0972 0.1035 0.1584 0.0889 0.0847]]
# Actual Class : 5
# --------------------------------------------------
# Out of the top  500  features  0 are present in query point

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-sig_clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_bigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0963 0.2178 0.0848 0.093  0.0869 0.0866 0.1665 0.0844 0.0838]]
# Actual Class : 7
# --------------------------------------------------
# Out of the top  500  features  0 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1366741157884974
# for alpha = 1e-05
# Log Loss : 1.109663494820241
# for alpha = 0.0001
# Log Loss : 0.979994149679308
# for alpha = 0.001
# Log Loss : 1.0288888999316081
# for alpha = 0.01
# Log Loss : 1.1949767776079947
# for alpha = 0.1
# Log Loss : 1.4690782149574497
# for alpha = 1
# Log Loss : 1.6954327551671222
# For values of best alpha =  0.0001 The train log loss is: 0.8022196212792767
# For values of best alpha =  0.0001 The cross validation log loss is: 0.979994149679308
# For values of best alpha =  0.0001 The test log loss is: 1.0083254464559013

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.979994149679308
# Number of mis-classified points : 0.3176691729323308
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0201 0.3412 0.0046 0.037  0.0302 0.0408 0.5175 0.0043 0.0042]]
# Actual Class : 5
# --------------------------------------------------
# 1 Text feature [downstream] present in test data point [True]
# 5 Text feature [activation] present in test data point [True]
# 11 Text feature [positive] present in test data point [True]
# 17 Text feature [constitutive] present in test data point [True]
# 20 Text feature [observations] present in test data point [True]
# 24 Text feature [days] present in test data point [True]
# 28 Text feature [overexpression] present in test data point [True]
# 32 Text feature [14] present in test data point [True]
# 33 Text feature [approximately] present in test data point [True]
# 36 Text feature [3b] present in test data point [True]
# 39 Text feature [advanced] present in test data point [True]
# 42 Text feature [without] present in test data point [True]
# 46 Text feature [properties] present in test data point [True]
# 47 Text feature [versus] present in test data point [True]
# 52 Text feature [inhibited] present in test data point [True]
# 55 Text feature [coding] present in test data point [True]
# 58 Text feature [enhanced] present in test data point [True]
# 66 Text feature [signaling] present in test data point [True]
# 69 Text feature [distinct] present in test data point [True]
# 71 Text feature [sensitive] present in test data point [True]
# 80 Text feature [activated] present in test data point [True]
# 82 Text feature [examined] present in test data point [True]
# 84 Text feature [32] present in test data point [True]
# 88 Text feature [leading] present in test data point [True]
# 89 Text feature [elevated] present in test data point [True]
# 90 Text feature [occur] present in test data point [True]
# 96 Text feature [phosphorylated] present in test data point [True]
# 97 Text feature [2b] present in test data point [True]
# 98 Text feature [3a] present in test data point [True]
# 105 Text feature [additional] present in test data point [True]
# 106 Text feature [wt] present in test data point [True]
# 114 Text feature [concentrations] present in test data point [True]
# 119 Text feature [factor] present in test data point [True]
# 121 Text feature [2a] present in test data point [True]
# 125 Text feature [25] present in test data point [True]
# 139 Text feature [increase] present in test data point [True]
# 144 Text feature [open] present in test data point [True]
# 145 Text feature [genomic] present in test data point [True]
# 146 Text feature [phospho] present in test data point [True]
# 147 Text feature [provided] present in test data point [True]
# 158 Text feature [pathways] present in test data point [True]
# 159 Text feature [s3] present in test data point [True]
# 160 Text feature [gfp] present in test data point [True]
# 161 Text feature [44] present in test data point [True]
# 163 Text feature [regions] present in test data point [True]
# 167 Text feature [extracellular] present in test data point [True]
# 170 Text feature [various] present in test data point [True]
# 174 Text feature [mediated] present in test data point [True]
# 179 Text feature [29] present in test data point [True]
# 180 Text feature [cancers] present in test data point [True]
# 181 Text feature [72] present in test data point [True]
# 182 Text feature [reverse] present in test data point [True]
# 183 Text feature [fig] present in test data point [True]
# 185 Text feature [nucleotide] present in test data point [True]
# 186 Text feature [resistant] present in test data point [True]
# 187 Text feature [manner] present in test data point [True]
# 189 Text feature [50] present in test data point [True]
# 191 Text feature [24] present in test data point [True]
# 192 Text feature [presence] present in test data point [True]
# 198 Text feature [previously] present in test data point [True]
# 199 Text feature [contribute] present in test data point [True]
# 201 Text feature [interestingly] present in test data point [True]
# 205 Text feature [mm] present in test data point [True]
# 207 Text feature [negative] present in test data point [True]
# 210 Text feature [lead] present in test data point [True]
# 212 Text feature [28] present in test data point [True]
# 218 Text feature [37] present in test data point [True]
# 221 Text feature [inhibitor] present in test data point [True]
# 226 Text feature [might] present in test data point [True]
# 229 Text feature [position] present in test data point [True]
# 230 Text feature [could] present in test data point [True]
# 231 Text feature [akt] present in test data point [True]
# 232 Text feature [cyclin] present in test data point [True]
# 234 Text feature [mutants] present in test data point [True]
# 235 Text feature [report] present in test data point [True]
# 237 Text feature [fold] present in test data point [True]
# 240 Text feature [survival] present in test data point [True]
# 242 Text feature [activating] present in test data point [True]
# 245 Text feature [standard] present in test data point [True]
# 246 Text feature [org] present in test data point [True]
# 248 Text feature [carcinoma] present in test data point [True]
# 249 Text feature [ligand] present in test data point [True]
# 250 Text feature [localization] present in test data point [True]
# 254 Text feature [ca] present in test data point [True]
# 257 Text feature [22] present in test data point [True]
# 259 Text feature [total] present in test data point [True]
# 261 Text feature [plasma] present in test data point [True]
# 262 Text feature [transcription] present in test data point [True]
# 263 Text feature [primers] present in test data point [True]
# 265 Text feature [liver] present in test data point [True]
# 267 Text feature [specific] present in test data point [True]
# 268 Text feature [supplementary] present in test data point [True]
# 269 Text feature [mechanisms] present in test data point [True]
# 270 Text feature [suggest] present in test data point [True]
# 273 Text feature [tumors] present in test data point [True]
# 275 Text feature [see] present in test data point [True]
# 276 Text feature [recently] present in test data point [True]
# 279 Text feature [substitution] present in test data point [True]
# 285 Text feature [sites] present in test data point [True]
# 289 Text feature [d1] present in test data point [True]
# 290 Text feature [high] present in test data point [True]
# 291 Text feature [cdk4] present in test data point [True]
# 296 Text feature [factors] present in test data point [True]
# 298 Text feature [include] present in test data point [True]
# 299 Text feature [2000] present in test data point [True]
# 300 Text feature [consistent] present in test data point [True]
# 302 Text feature [level] present in test data point [True]
# 304 Text feature [increased] present in test data point [True]
# 311 Text feature [materials] present in test data point [True]
# 313 Text feature [initial] present in test data point [True]
# 315 Text feature [phosphorylation] present in test data point [True]
# 320 Text feature [effective] present in test data point [True]
# 321 Text feature [approach] present in test data point [True]
# 327 Text feature [000] present in test data point [True]
# 328 Text feature [established] present in test data point [True]
# 329 Text feature [41] present in test data point [True]
# 330 Text feature [green] present in test data point [True]
# 332 Text feature [hours] present in test data point [True]
# 333 Text feature [mutant] present in test data point [True]
# 336 Text feature [nuclear] present in test data point [True]
# 338 Text feature [10] present in test data point [True]
# 340 Text feature [35] present in test data point [True]
# 342 Text feature [published] present in test data point [True]
# 344 Text feature [two] present in test data point [True]
# 347 Text feature [resulting] present in test data point [True]
# 349 Text feature [plates] present in test data point [True]
# 352 Text feature [fact] present in test data point [True]
# 353 Text feature [alternative] present in test data point [True]
# 354 Text feature [dependent] present in test data point [True]
# 356 Text feature [independent] present in test data point [True]
# 358 Text feature [driven] present in test data point [True]
# 359 Text feature [generated] present in test data point [True]
# 369 Text feature [dose] present in test data point [True]
# 371 Text feature [incubated] present in test data point [True]
# 373 Text feature [70] present in test data point [True]
# 375 Text feature [prior] present in test data point [True]
# 376 Text feature [corresponding] present in test data point [True]
# 378 Text feature [note] present in test data point [True]
# 383 Text feature [furthermore] present in test data point [True]
# 386 Text feature [inhibition] present in test data point [True]
# 387 Text feature [time] present in test data point [True]
# 391 Text feature [years] present in test data point [True]
# 392 Text feature [chromosome] present in test data point [True]
# 393 Text feature [treatment] present in test data point [True]
# 396 Text feature [form] present in test data point [True]
# 397 Text feature [16] present in test data point [True]
# 398 Text feature [mutated] present in test data point [True]
# 401 Text feature [available] present in test data point [True]
# 402 Text feature [either] present in test data point [True]
# 403 Text feature [tissue] present in test data point [True]
# 405 Text feature [higher] present in test data point [True]
# 406 Text feature [therapy] present in test data point [True]
# 407 Text feature [within] present in test data point [True]
# 409 Text feature [led] present in test data point [True]
# 411 Text feature [oncogenic] present in test data point [True]
# 412 Text feature [mechanism] present in test data point [True]
# 414 Text feature [malignant] present in test data point [True]
# 415 Text feature [free] present in test data point [True]
# 417 Text feature [limited] present in test data point [True]
# 418 Text feature [kinase] present in test data point [True]
# 420 Text feature [57] present in test data point [True]
# 421 Text feature [absence] present in test data point [True]
# 422 Text feature [induction] present in test data point [True]
# 424 Text feature [multiple] present in test data point [True]
# 426 Text feature [12] present in test data point [True]
# 430 Text feature [model] present in test data point [True]
# 432 Text feature [region] present in test data point [True]
# 440 Text feature [interact] present in test data point [True]
# 442 Text feature [expressed] present in test data point [True]
# 443 Text feature [regulation] present in test data point [True]
# 444 Text feature [sensitivity] present in test data point [True]
# 445 Text feature [cells] present in test data point [True]
# 450 Text feature [showed] present in test data point [True]
# 451 Text feature [common] present in test data point [True]
# 452 Text feature [experiments] present in test data point [True]
# 453 Text feature [concentration] present in test data point [True]
# 456 Text feature [obtained] present in test data point [True]
# 465 Text feature [disease] present in test data point [True]
# 466 Text feature [determine] present in test data point [True]
# 467 Text feature [signal] present in test data point [True]
# 468 Text feature [general] present in test data point [True]
# 469 Text feature [mean] present in test data point [True]
# 470 Text feature [part] present in test data point [True]
# 471 Text feature [molecular] present in test data point [True]
# 473 Text feature [cycle] present in test data point [True]
# 474 Text feature [18] present in test data point [True]
# 476 Text feature [among] present in test data point [True]
# 479 Text feature [another] present in test data point [True]
# 480 Text feature [data] present in test data point [True]
# 481 Text feature [per] present in test data point [True]
# 484 Text feature [constitutively] present in test data point [True]
# 485 Text feature [constructs] present in test data point [True]
# 486 Text feature [respectively] present in test data point [True]
# 487 Text feature [table] present in test data point [True]
# 492 Text feature [reported] present in test data point [True]
# 493 Text feature [metastatic] present in test data point [True]
# 494 Text feature [harboring] present in test data point [True]
# 495 Text feature [also] present in test data point [True]
# 498 Text feature [sequenced] present in test data point [True]
# Out of the top  500  features  199 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0202 0.1862 0.0046 0.0134 0.0216 0.0856 0.6669 0.0009 0.0007]]
# Actual Class : 7
# --------------------------------------------------
# 1 Text feature [downstream] present in test data point [True]
# 2 Text feature [insertion] present in test data point [True]
# 5 Text feature [activation] present in test data point [True]
# 6 Text feature [colony] present in test data point [True]
# 11 Text feature [positive] present in test data point [True]
# 13 Text feature [transformed] present in test data point [True]
# 28 Text feature [overexpression] present in test data point [True]
# 32 Text feature [14] present in test data point [True]
# 36 Text feature [3b] present in test data point [True]
# 37 Text feature [ras] present in test data point [True]
# 42 Text feature [without] present in test data point [True]
# 46 Text feature [properties] present in test data point [True]
# 48 Text feature [fusion] present in test data point [True]
# 52 Text feature [inhibited] present in test data point [True]
# 66 Text feature [signaling] present in test data point [True]
# 68 Text feature [61] present in test data point [True]
# 69 Text feature [distinct] present in test data point [True]
# 71 Text feature [sensitive] present in test data point [True]
# 76 Text feature [leukemia] present in test data point [True]
# 80 Text feature [activated] present in test data point [True]
# 82 Text feature [examined] present in test data point [True]
# 84 Text feature [32] present in test data point [True]
# 89 Text feature [elevated] present in test data point [True]
# 96 Text feature [phosphorylated] present in test data point [True]
# 98 Text feature [3a] present in test data point [True]
# 105 Text feature [additional] present in test data point [True]
# 112 Text feature [chromosomal] present in test data point [True]
# 114 Text feature [concentrations] present in test data point [True]
# 117 Text feature [blood] present in test data point [True]
# 119 Text feature [factor] present in test data point [True]
# 123 Text feature [frame] present in test data point [True]
# 125 Text feature [25] present in test data point [True]
# 135 Text feature [features] present in test data point [True]
# 143 Text feature [braf] present in test data point [True]
# 145 Text feature [genomic] present in test data point [True]
# 147 Text feature [provided] present in test data point [True]
# 149 Text feature [activate] present in test data point [True]
# 158 Text feature [pathways] present in test data point [True]
# 159 Text feature [s3] present in test data point [True]
# 162 Text feature [frequent] present in test data point [True]
# 181 Text feature [72] present in test data point [True]
# 182 Text feature [reverse] present in test data point [True]
# 183 Text feature [fig] present in test data point [True]
# 185 Text feature [nucleotide] present in test data point [True]
# 188 Text feature [jak2] present in test data point [True]
# 189 Text feature [50] present in test data point [True]
# 191 Text feature [24] present in test data point [True]
# 192 Text feature [presence] present in test data point [True]
# 198 Text feature [previously] present in test data point [True]
# 200 Text feature [43] present in test data point [True]
# 207 Text feature [negative] present in test data point [True]
# 212 Text feature [28] present in test data point [True]
# 218 Text feature [37] present in test data point [True]
# 221 Text feature [inhibitor] present in test data point [True]
# 223 Text feature [characteristics] present in test data point [True]
# 240 Text feature [survival] present in test data point [True]
# 242 Text feature [activating] present in test data point [True]
# 245 Text feature [standard] present in test data point [True]
# 246 Text feature [org] present in test data point [True]
# 249 Text feature [ligand] present in test data point [True]
# 257 Text feature [22] present in test data point [True]
# 259 Text feature [total] present in test data point [True]
# 260 Text feature [nf1] present in test data point [True]
# 262 Text feature [transcription] present in test data point [True]
# 268 Text feature [supplementary] present in test data point [True]
# 274 Text feature [associated] present in test data point [True]
# 280 Text feature [mapk] present in test data point [True]
# 281 Text feature [current] present in test data point [True]
# 290 Text feature [high] present in test data point [True]
# 296 Text feature [factors] present in test data point [True]
# 300 Text feature [consistent] present in test data point [True]
# 301 Text feature [end] present in test data point [True]
# 304 Text feature [increased] present in test data point [True]
# 305 Text feature [transforming] present in test data point [True]
# 315 Text feature [phosphorylation] present in test data point [True]
# 317 Text feature [deletion] present in test data point [True]
# 320 Text feature [effective] present in test data point [True]
# 321 Text feature [approach] present in test data point [True]
# 322 Text feature [suppression] present in test data point [True]
# 327 Text feature [000] present in test data point [True]
# 328 Text feature [established] present in test data point [True]
# 329 Text feature [41] present in test data point [True]
# 331 Text feature [strong] present in test data point [True]
# 334 Text feature [kras] present in test data point [True]
# 337 Text feature [49] present in test data point [True]
# 338 Text feature [10] present in test data point [True]
# 339 Text feature [indicate] present in test data point [True]
# 340 Text feature [35] present in test data point [True]
# 343 Text feature [nm] present in test data point [True]
# 344 Text feature [two] present in test data point [True]
# 347 Text feature [resulting] present in test data point [True]
# 354 Text feature [dependent] present in test data point [True]
# 355 Text feature [fusions] present in test data point [True]
# 356 Text feature [independent] present in test data point [True]
# 365 Text feature [lesions] present in test data point [True]
# 380 Text feature [seen] present in test data point [True]
# 382 Text feature [ph] present in test data point [True]
# 383 Text feature [furthermore] present in test data point [True]
# 384 Text feature [diagnosis] present in test data point [True]
# 386 Text feature [inhibition] present in test data point [True]
# 391 Text feature [years] present in test data point [True]
# 392 Text feature [chromosome] present in test data point [True]
# 393 Text feature [treatment] present in test data point [True]
# 397 Text feature [16] present in test data point [True]
# 401 Text feature [available] present in test data point [True]
# 402 Text feature [either] present in test data point [True]
# 405 Text feature [higher] present in test data point [True]
# 406 Text feature [therapy] present in test data point [True]
# 408 Text feature [expressing] present in test data point [True]
# 411 Text feature [oncogenic] present in test data point [True]
# 414 Text feature [malignant] present in test data point [True]
# 415 Text feature [free] present in test data point [True]
# 417 Text feature [limited] present in test data point [True]
# 418 Text feature [kinase] present in test data point [True]
# 422 Text feature [induction] present in test data point [True]
# 424 Text feature [multiple] present in test data point [True]
# 426 Text feature [12] present in test data point [True]
# 430 Text feature [model] present in test data point [True]
# 431 Text feature [flt3] present in test data point [True]
# 438 Text feature [recurrent] present in test data point [True]
# 442 Text feature [expressed] present in test data point [True]
# 443 Text feature [regulation] present in test data point [True]
# 445 Text feature [cells] present in test data point [True]
# 451 Text feature [common] present in test data point [True]
# 452 Text feature [experiments] present in test data point [True]
# 453 Text feature [concentration] present in test data point [True]
# 454 Text feature [together] present in test data point [True]
# 455 Text feature [non] present in test data point [True]
# 456 Text feature [obtained] present in test data point [True]
# 465 Text feature [disease] present in test data point [True]
# 466 Text feature [determine] present in test data point [True]
# 469 Text feature [mean] present in test data point [True]
# 471 Text feature [molecular] present in test data point [True]
# 472 Text feature [ba] present in test data point [True]
# 474 Text feature [18] present in test data point [True]
# 476 Text feature [among] present in test data point [True]
# 480 Text feature [data] present in test data point [True]
# 481 Text feature [per] present in test data point [True]
# 482 Text feature [classified] present in test data point [True]
# 486 Text feature [respectively] present in test data point [True]
# 487 Text feature [table] present in test data point [True]
# 488 Text feature [59] present in test data point [True]
# 490 Text feature [cohort] present in test data point [True]
# 492 Text feature [reported] present in test data point [True]
# 494 Text feature [harboring] present in test data point [True]
# 495 Text feature [also] present in test data point [True]
# 499 Text feature [f3] present in test data point [True]
# Out of the top  500  features  147 are present in query point

# %% [markdown]
# ### Logistic regression with CountVectorizer(Unigram)

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_unigram, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_unigram, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_unigram)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_unigram, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_unigram, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_unigram)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_unigram)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_unigram)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3606601683766293
# for alpha = 1e-05
# Log Loss : 1.3655206064892407
# for alpha = 0.0001
# Log Loss : 1.3271278255662202
# for alpha = 0.001
# Log Loss : 1.1340011033822526
# for alpha = 0.01
# Log Loss : 1.1341603001586533
# for alpha = 0.1
# Log Loss : 1.258696955452913
# for alpha = 1
# Log Loss : 1.5106513189807278
# for alpha = 10
# Log Loss : 1.5647853504363265
# for alpha = 100
# Log Loss : 1.5706385347245038
# For values of best alpha =  0.001 The train log loss is: 0.679347719345643
# For values of best alpha =  0.001 The cross validation log loss is: 1.1340011033822526
# For values of best alpha =  0.001 The test log loss is: 1.0837469227206866

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_unigram, train_y, cv_x_onehotCoding_unigram, cv_y, clf)
# Out:
# Log loss : 1.1340011033822526
# Number of mis-classified points : 0.33646616541353386
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
def get_impfeature_names_unigram(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
# from tabulate import tabulate
sig_clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
sig_clf.fit(train_x_onehotCoding_unigram,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_unigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_unigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-sig_clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_unigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index], test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0266 0.5582 0.0093 0.0831 0.0211 0.0389 0.2489 0.0066 0.0073]]
# Actual Class : 5
# --------------------------------------------------
# 107 Text feature [0449] present in test data point [True]
# 119 Text feature [d473h] present in test data point [True]
# 161 Text feature [therapeutically] present in test data point [True]
# 242 Text feature [tm6] present in test data point [True]
# 480 Text feature [pd] present in test data point [True]
# 483 Text feature [gdc] present in test data point [True]
# Out of the top  500  features  6 are present in query point

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_unigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_unigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_unigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0476 0.3084 0.0217 0.0358 0.0352 0.0297 0.4797 0.021  0.0211]]
# Actual Class : 7
# --------------------------------------------------
# 156 Text feature [transforming] present in test data point [True]
# 185 Text feature [stat5] present in test data point [True]
# 215 Text feature [downstream] present in test data point [True]
# 232 Text feature [transformed] present in test data point [True]
# 282 Text feature [cubic] present in test data point [True]
# 295 Text feature [ranbp2] present in test data point [True]
# 299 Text feature [stat] present in test data point [True]
# 347 Text feature [ba] present in test data point [True]
# 350 Text feature [activated] present in test data point [True]
# 424 Text feature [f3] present in test data point [True]
# 459 Text feature [expressing] present in test data point [True]
# Out of the top  500  features  11 are present in query point

# %% [markdown]
# ### Logistic regression with CountVectorizer(Bigram)

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_bigram, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_bigram, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_bigram)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_bigram, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_bigram, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_bigram)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_bigram)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_bigram)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.5351698154681197
# for alpha = 1e-05
# Log Loss : 1.5445080943847833
# for alpha = 0.0001
# Log Loss : 1.5415229584808576
# for alpha = 0.001
# Log Loss : 1.5123858100575511
# for alpha = 0.01
# Log Loss : 1.2449038723274923
# for alpha = 0.1
# Log Loss : 1.187041185436121
# for alpha = 1
# Log Loss : 1.2199203842662645
# for alpha = 10
# Log Loss : 1.2595126104401355
# for alpha = 100
# Log Loss : 1.2695233322069972
# For values of best alpha =  0.1 The train log loss is: 0.77850596018
# For values of best alpha =  0.1 The cross validation log loss is: 1.187041185436121
# For values of best alpha =  0.1 The test log loss is: 1.2079708645028029

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_bigram, train_y, cv_x_onehotCoding_bigram, cv_y, clf)
# Out:
# Log loss : 1.187041185436121
# Number of mis-classified points : 0.36466165413533835
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
def get_impfeature_names_bigram(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=2, ngram_range=(1,2))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
# from tabulate import tabulate
sig_clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
sig_clf.fit(train_x_onehotCoding_bigram,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-sig_clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_bigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],
                     test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1153 0.1482 0.0825 0.1217 0.0913 0.0975 0.1826 0.0807 0.0803]]
# Actual Class : 5
# --------------------------------------------------
# 42 Text feature [constitutive] present in test data point [True]
# 60 Text feature [constitutively] present in test data point [True]
# 306 Text feature [nude] present in test data point [True]
# 454 Text feature [subcutaneously] present in test data point [True]
# Out of the top  500  features  4 are present in query point

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigram[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigram[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-sig_clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_bigram(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0907 0.2155 0.0755 0.0884 0.0783 0.0784 0.2236 0.0747 0.0749]]
# Actual Class : 7
# --------------------------------------------------
# 56 Text feature [stat5] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1228214383860473
# for C = 0.0001
# Log Loss : 1.0683425857472266
# for C = 0.001
# Log Loss : 1.0736532275001078
# for C = 0.01
# Log Loss : 1.2380032134658148
# for C = 0.1
# Log Loss : 1.5647784606205741
# for C = 1
# Log Loss : 1.6879073960123672
# for C = 10
# Log Loss : 1.6879074296080423
# for C = 100
# Log Loss : 1.6879074645761583
# For values of best alpha =  0.0001 The train log loss is: 0.9579984214559089
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0683425857472266
# For values of best alpha =  0.0001 The test log loss is: 1.1103934840485612

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.0683425857472266
# Number of mis-classified points : 0.32894736842105265
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0597 0.2893 0.0167 0.0423 0.0463 0.1077 0.4183 0.0097 0.0101]]
# Actual Class : 5
# --------------------------------------------------
# 0 Text feature [downstream] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 8 Text feature [constitutive] present in test data point [True]
# 10 Text feature [positive] present in test data point [True]
# 13 Text feature [observations] present in test data point [True]
# 23 Text feature [coding] present in test data point [True]
# 27 Text feature [days] present in test data point [True]
# 28 Text feature [3b] present in test data point [True]
# 29 Text feature [approximately] present in test data point [True]
# 33 Text feature [inhibited] present in test data point [True]
# 37 Text feature [14] present in test data point [True]
# 38 Text feature [versus] present in test data point [True]
# 41 Text feature [without] present in test data point [True]
# 42 Text feature [wt] present in test data point [True]
# 43 Text feature [advanced] present in test data point [True]
# 44 Text feature [leading] present in test data point [True]
# 47 Text feature [distinct] present in test data point [True]
# 48 Text feature [occur] present in test data point [True]
# 49 Text feature [properties] present in test data point [True]
# 51 Text feature [32] present in test data point [True]
# 55 Text feature [3a] present in test data point [True]
# 56 Text feature [overexpression] present in test data point [True]
# 58 Text feature [additional] present in test data point [True]
# 62 Text feature [2a] present in test data point [True]
# 113 Text feature [examined] present in test data point [True]
# 115 Text feature [elevated] present in test data point [True]
# 117 Text feature [nucleotide] present in test data point [True]
# 118 Text feature [signaling] present in test data point [True]
# 119 Text feature [sensitive] present in test data point [True]
# 120 Text feature [increase] present in test data point [True]
# 123 Text feature [factor] present in test data point [True]
# 124 Text feature [fig] present in test data point [True]
# 125 Text feature [lead] present in test data point [True]
# 126 Text feature [phospho] present in test data point [True]
# 128 Text feature [phosphorylated] present in test data point [True]
# 130 Text feature [enhanced] present in test data point [True]
# 131 Text feature [genomic] present in test data point [True]
# 133 Text feature [24] present in test data point [True]
# 135 Text feature [2b] present in test data point [True]
# 136 Text feature [various] present in test data point [True]
# 137 Text feature [specific] present in test data point [True]
# 138 Text feature [cancers] present in test data point [True]
# 139 Text feature [pathways] present in test data point [True]
# 141 Text feature [s3] present in test data point [True]
# 143 Text feature [mm] present in test data point [True]
# 144 Text feature [standard] present in test data point [True]
# 146 Text feature [regions] present in test data point [True]
# 148 Text feature [50] present in test data point [True]
# 149 Text feature [might] present in test data point [True]
# 150 Text feature [gfp] present in test data point [True]
# 151 Text feature [29] present in test data point [True]
# 153 Text feature [25] present in test data point [True]
# 155 Text feature [activated] present in test data point [True]
# 157 Text feature [increased] present in test data point [True]
# 159 Text feature [position] present in test data point [True]
# 162 Text feature [72] present in test data point [True]
# 164 Text feature [previously] present in test data point [True]
# 165 Text feature [interestingly] present in test data point [True]
# 166 Text feature [44] present in test data point [True]
# 168 Text feature [mediated] present in test data point [True]
# 169 Text feature [negative] present in test data point [True]
# 170 Text feature [primers] present in test data point [True]
# 171 Text feature [could] present in test data point [True]
# 174 Text feature [presence] present in test data point [True]
# 175 Text feature [plates] present in test data point [True]
# 176 Text feature [concentrations] present in test data point [True]
# 179 Text feature [open] present in test data point [True]
# 180 Text feature [org] present in test data point [True]
# 181 Text feature [transcription] present in test data point [True]
# 182 Text feature [report] present in test data point [True]
# 185 Text feature [total] present in test data point [True]
# 187 Text feature [supplementary] present in test data point [True]
# 188 Text feature [contribute] present in test data point [True]
# 190 Text feature [ca] present in test data point [True]
# 192 Text feature [resistant] present in test data point [True]
# 193 Text feature [37] present in test data point [True]
# 194 Text feature [35] present in test data point [True]
# 198 Text feature [28] present in test data point [True]
# 199 Text feature [provided] present in test data point [True]
# 200 Text feature [mutants] present in test data point [True]
# 204 Text feature [consistent] present in test data point [True]
# 205 Text feature [high] present in test data point [True]
# 206 Text feature [ligand] present in test data point [True]
# 207 Text feature [extracellular] present in test data point [True]
# 210 Text feature [published] present in test data point [True]
# 216 Text feature [tumors] present in test data point [True]
# 221 Text feature [incubated] present in test data point [True]
# 222 Text feature [interact] present in test data point [True]
# 226 Text feature [plasma] present in test data point [True]
# 227 Text feature [level] present in test data point [True]
# 228 Text feature [fold] present in test data point [True]
# 232 Text feature [either] present in test data point [True]
# 233 Text feature [resulting] present in test data point [True]
# 235 Text feature [reverse] present in test data point [True]
# 236 Text feature [activating] present in test data point [True]
# 237 Text feature [fact] present in test data point [True]
# 238 Text feature [furthermore] present in test data point [True]
# 240 Text feature [include] present in test data point [True]
# 241 Text feature [carcinoma] present in test data point [True]
# 242 Text feature [alternative] present in test data point [True]
# 243 Text feature [materials] present in test data point [True]
# 245 Text feature [suggest] present in test data point [True]
# 248 Text feature [substitution] present in test data point [True]
# 249 Text feature [initial] present in test data point [True]
# 251 Text feature [manner] present in test data point [True]
# 252 Text feature [mechanisms] present in test data point [True]
# 253 Text feature [10] present in test data point [True]
# 254 Text feature [inhibitor] present in test data point [True]
# 258 Text feature [survival] present in test data point [True]
# 259 Text feature [two] present in test data point [True]
# 260 Text feature [established] present in test data point [True]
# 263 Text feature [41] present in test data point [True]
# 265 Text feature [12] present in test data point [True]
# 267 Text feature [d1] present in test data point [True]
# 268 Text feature [factors] present in test data point [True]
# 269 Text feature [generated] present in test data point [True]
# 270 Text feature [cyclin] present in test data point [True]
# 271 Text feature [sites] present in test data point [True]
# 272 Text feature [available] present in test data point [True]
# 274 Text feature [dependent] present in test data point [True]
# 275 Text feature [effective] present in test data point [True]
# 343 Text feature [induction] present in test data point [True]
# 344 Text feature [recently] present in test data point [True]
# 347 Text feature [free] present in test data point [True]
# 351 Text feature [driven] present in test data point [True]
# 353 Text feature [harboring] present in test data point [True]
# 355 Text feature [within] present in test data point [True]
# 356 Text feature [prior] present in test data point [True]
# 358 Text feature [akt] present in test data point [True]
# 360 Text feature [22] present in test data point [True]
# 361 Text feature [another] present in test data point [True]
# 362 Text feature [000] present in test data point [True]
# 363 Text feature [independent] present in test data point [True]
# 364 Text feature [absence] present in test data point [True]
# 365 Text feature [time] present in test data point [True]
# 367 Text feature [see] present in test data point [True]
# 368 Text feature [chromosome] present in test data point [True]
# 369 Text feature [corresponding] present in test data point [True]
# 372 Text feature [malignant] present in test data point [True]
# 374 Text feature [years] present in test data point [True]
# 376 Text feature [note] present in test data point [True]
# 377 Text feature [introduction] present in test data point [True]
# 378 Text feature [57] present in test data point [True]
# 380 Text feature [higher] present in test data point [True]
# 381 Text feature [70] present in test data point [True]
# 383 Text feature [obtained] present in test data point [True]
# 384 Text feature [mutant] present in test data point [True]
# 386 Text feature [2000] present in test data point [True]
# 388 Text feature [series] present in test data point [True]
# 390 Text feature [nuclear] present in test data point [True]
# 394 Text feature [per] present in test data point [True]
# 395 Text feature [molecular] present in test data point [True]
# 398 Text feature [determine] present in test data point [True]
# 400 Text feature [phosphorylation] present in test data point [True]
# 402 Text feature [approach] present in test data point [True]
# 404 Text feature [cdk4] present in test data point [True]
# 406 Text feature [association] present in test data point [True]
# 408 Text feature [sequenced] present in test data point [True]
# 410 Text feature [form] present in test data point [True]
# 411 Text feature [american] present in test data point [True]
# 412 Text feature [common] present in test data point [True]
# 413 Text feature [showed] present in test data point [True]
# 415 Text feature [table] present in test data point [True]
# 416 Text feature [one] present in test data point [True]
# 417 Text feature [tumor] present in test data point [True]
# 420 Text feature [found] present in test data point [True]
# 421 Text feature [model] present in test data point [True]
# 422 Text feature [treatment] present in test data point [True]
# 423 Text feature [conditions] present in test data point [True]
# 424 Text feature [liver] present in test data point [True]
# 425 Text feature [hours] present in test data point [True]
# 426 Text feature [regulation] present in test data point [True]
# 428 Text feature [displayed] present in test data point [True]
# 430 Text feature [18] present in test data point [True]
# 431 Text feature [identification] present in test data point [True]
# 433 Text feature [system] present in test data point [True]
# 434 Text feature [led] present in test data point [True]
# 435 Text feature [three] present in test data point [True]
# 437 Text feature [respectively] present in test data point [True]
# 442 Text feature [green] present in test data point [True]
# 443 Text feature [targeted] present in test data point [True]
# 445 Text feature [second] present in test data point [True]
# 446 Text feature [data] present in test data point [True]
# 448 Text feature [16] present in test data point [True]
# 449 Text feature [tissue] present in test data point [True]
# 451 Text feature [reaction] present in test data point [True]
# 452 Text feature [methods] present in test data point [True]
# 453 Text feature [experiments] present in test data point [True]
# 454 Text feature [localization] present in test data point [True]
# 455 Text feature [general] present in test data point [True]
# 456 Text feature [analyzed] present in test data point [True]
# 458 Text feature [39] present in test data point [True]
# 459 Text feature [mechanism] present in test data point [True]
# 460 Text feature [reported] present in test data point [True]
# 461 Text feature [region] present in test data point [True]
# 462 Text feature [also] present in test data point [True]
# 464 Text feature [indicating] present in test data point [True]
# 465 Text feature [ability] present in test data point [True]
# 466 Text feature [cells] present in test data point [True]
# 467 Text feature [mean] present in test data point [True]
# 469 Text feature [determined] present in test data point [True]
# 471 Text feature [tested] present in test data point [True]
# 472 Text feature [4a] present in test data point [True]
# 474 Text feature [sensitivity] present in test data point [True]
# 476 Text feature [inhibition] present in test data point [True]
# 477 Text feature [first] present in test data point [True]
# 481 Text feature [cycle] present in test data point [True]
# 482 Text feature [like] present in test data point [True]
# 485 Text feature [well] present in test data point [True]
# 487 Text feature [constitutively] present in test data point [True]
# 488 Text feature [induced] present in test data point [True]
# 490 Text feature [key] present in test data point [True]
# 493 Text feature [inhibitory] present in test data point [True]
# 494 Text feature [limited] present in test data point [True]
# 495 Text feature [may] present in test data point [True]
# 496 Text feature [representative] present in test data point [True]
# 497 Text feature [concentration] present in test data point [True]
# 498 Text feature [34] present in test data point [True]
# Out of the top  500  features  218 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0762 0.2007 0.0218 0.0766 0.0591 0.0796 0.4805 0.0038 0.0019]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [downstream] present in test data point [True]
# 1 Text feature [insertion] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 7 Text feature [colony] present in test data point [True]
# 10 Text feature [positive] present in test data point [True]
# 11 Text feature [transformed] present in test data point [True]
# 24 Text feature [fusion] present in test data point [True]
# 28 Text feature [3b] present in test data point [True]
# 30 Text feature [frame] present in test data point [True]
# 33 Text feature [inhibited] present in test data point [True]
# 35 Text feature [ras] present in test data point [True]
# 37 Text feature [14] present in test data point [True]
# 39 Text feature [61] present in test data point [True]
# 41 Text feature [without] present in test data point [True]
# 47 Text feature [distinct] present in test data point [True]
# 49 Text feature [properties] present in test data point [True]
# 51 Text feature [32] present in test data point [True]
# 55 Text feature [3a] present in test data point [True]
# 56 Text feature [overexpression] present in test data point [True]
# 58 Text feature [additional] present in test data point [True]
# 59 Text feature [chromosomal] present in test data point [True]
# 113 Text feature [examined] present in test data point [True]
# 115 Text feature [elevated] present in test data point [True]
# 117 Text feature [nucleotide] present in test data point [True]
# 118 Text feature [signaling] present in test data point [True]
# 119 Text feature [sensitive] present in test data point [True]
# 123 Text feature [factor] present in test data point [True]
# 124 Text feature [fig] present in test data point [True]
# 128 Text feature [phosphorylated] present in test data point [True]
# 131 Text feature [genomic] present in test data point [True]
# 133 Text feature [24] present in test data point [True]
# 139 Text feature [pathways] present in test data point [True]
# 141 Text feature [s3] present in test data point [True]
# 144 Text feature [standard] present in test data point [True]
# 148 Text feature [50] present in test data point [True]
# 152 Text feature [activate] present in test data point [True]
# 153 Text feature [25] present in test data point [True]
# 154 Text feature [features] present in test data point [True]
# 155 Text feature [activated] present in test data point [True]
# 157 Text feature [increased] present in test data point [True]
# 161 Text feature [blood] present in test data point [True]
# 162 Text feature [72] present in test data point [True]
# 163 Text feature [jak2] present in test data point [True]
# 164 Text feature [previously] present in test data point [True]
# 169 Text feature [negative] present in test data point [True]
# 172 Text feature [frequent] present in test data point [True]
# 174 Text feature [presence] present in test data point [True]
# 176 Text feature [concentrations] present in test data point [True]
# 177 Text feature [characteristics] present in test data point [True]
# 178 Text feature [leukemia] present in test data point [True]
# 180 Text feature [org] present in test data point [True]
# 181 Text feature [transcription] present in test data point [True]
# 183 Text feature [current] present in test data point [True]
# 184 Text feature [braf] present in test data point [True]
# 185 Text feature [total] present in test data point [True]
# 187 Text feature [supplementary] present in test data point [True]
# 193 Text feature [37] present in test data point [True]
# 194 Text feature [35] present in test data point [True]
# 198 Text feature [28] present in test data point [True]
# 199 Text feature [provided] present in test data point [True]
# 202 Text feature [mapk] present in test data point [True]
# 204 Text feature [consistent] present in test data point [True]
# 205 Text feature [high] present in test data point [True]
# 206 Text feature [ligand] present in test data point [True]
# 208 Text feature [nf1] present in test data point [True]
# 224 Text feature [43] present in test data point [True]
# 231 Text feature [associated] present in test data point [True]
# 232 Text feature [either] present in test data point [True]
# 233 Text feature [resulting] present in test data point [True]
# 234 Text feature [59] present in test data point [True]
# 235 Text feature [reverse] present in test data point [True]
# 236 Text feature [activating] present in test data point [True]
# 238 Text feature [furthermore] present in test data point [True]
# 239 Text feature [49] present in test data point [True]
# 250 Text feature [deletion] present in test data point [True]
# 253 Text feature [10] present in test data point [True]
# 254 Text feature [inhibitor] present in test data point [True]
# 255 Text feature [fusions] present in test data point [True]
# 256 Text feature [nm] present in test data point [True]
# 257 Text feature [suppression] present in test data point [True]
# 258 Text feature [survival] present in test data point [True]
# 259 Text feature [two] present in test data point [True]
# 260 Text feature [established] present in test data point [True]
# 263 Text feature [41] present in test data point [True]
# 265 Text feature [12] present in test data point [True]
# 268 Text feature [factors] present in test data point [True]
# 272 Text feature [available] present in test data point [True]
# 273 Text feature [diagnosis] present in test data point [True]
# 274 Text feature [dependent] present in test data point [True]
# 275 Text feature [effective] present in test data point [True]
# 343 Text feature [induction] present in test data point [True]
# 345 Text feature [strong] present in test data point [True]
# 346 Text feature [seen] present in test data point [True]
# 347 Text feature [free] present in test data point [True]
# 350 Text feature [lesions] present in test data point [True]
# 352 Text feature [recurrent] present in test data point [True]
# 353 Text feature [harboring] present in test data point [True]
# 360 Text feature [22] present in test data point [True]
# 362 Text feature [000] present in test data point [True]
# 363 Text feature [independent] present in test data point [True]
# 368 Text feature [chromosome] present in test data point [True]
# 372 Text feature [malignant] present in test data point [True]
# 373 Text feature [together] present in test data point [True]
# 374 Text feature [years] present in test data point [True]
# 379 Text feature [end] present in test data point [True]
# 380 Text feature [higher] present in test data point [True]
# 383 Text feature [obtained] present in test data point [True]
# 393 Text feature [ph] present in test data point [True]
# 394 Text feature [per] present in test data point [True]
# 395 Text feature [molecular] present in test data point [True]
# 398 Text feature [determine] present in test data point [True]
# 400 Text feature [phosphorylation] present in test data point [True]
# 402 Text feature [approach] present in test data point [True]
# 407 Text feature [expressing] present in test data point [True]
# 411 Text feature [american] present in test data point [True]
# 412 Text feature [common] present in test data point [True]
# 415 Text feature [table] present in test data point [True]
# 416 Text feature [one] present in test data point [True]
# 417 Text feature [tumor] present in test data point [True]
# 420 Text feature [found] present in test data point [True]
# 421 Text feature [model] present in test data point [True]
# 422 Text feature [treatment] present in test data point [True]
# 426 Text feature [regulation] present in test data point [True]
# 430 Text feature [18] present in test data point [True]
# 431 Text feature [identification] present in test data point [True]
# 437 Text feature [respectively] present in test data point [True]
# 438 Text feature [indicate] present in test data point [True]
# 439 Text feature [classified] present in test data point [True]
# 444 Text feature [transforming] present in test data point [True]
# 445 Text feature [second] present in test data point [True]
# 446 Text feature [data] present in test data point [True]
# 448 Text feature [16] present in test data point [True]
# 451 Text feature [reaction] present in test data point [True]
# 452 Text feature [methods] present in test data point [True]
# 453 Text feature [experiments] present in test data point [True]
# 458 Text feature [39] present in test data point [True]
# 460 Text feature [reported] present in test data point [True]
# 462 Text feature [also] present in test data point [True]
# 465 Text feature [ability] present in test data point [True]
# 466 Text feature [cells] present in test data point [True]
# 467 Text feature [mean] present in test data point [True]
# 471 Text feature [tested] present in test data point [True]
# 475 Text feature [flt3] present in test data point [True]
# 476 Text feature [inhibition] present in test data point [True]
# 479 Text feature [cohort] present in test data point [True]
# 480 Text feature [remaining] present in test data point [True]
# 482 Text feature [like] present in test data point [True]
# 484 Text feature [kras] present in test data point [True]
# 485 Text feature [well] present in test data point [True]
# 492 Text feature [characterized] present in test data point [True]
# 493 Text feature [inhibitory] present in test data point [True]
# 494 Text feature [limited] present in test data point [True]
# 495 Text feature [may] present in test data point [True]
# 497 Text feature [concentration] present in test data point [True]
# 498 Text feature [34] present in test data point [True]
# Out of the top  500  features  155 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2454627212532015
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2821237347236702
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2288645142821102
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2752734533418901
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2205241727949216
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2654877556998383
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2160766572936332
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.263904526351762
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2146713245736078
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.260659128622379
# For values of best estimator =  2000 The train log loss is: 0.8594329615262853
# For values of best estimator =  2000 The cross validation log loss is: 1.2146713245736078
# For values of best estimator =  2000 The test log loss is: 1.1826018802618026

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.2146713245736076
# Number of mis-classified points : 0.40601503759398494
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0552 0.2232 0.0215 0.0564 0.0477 0.0502 0.5309 0.0077 0.007 ]]
# Actual Class : 5
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [phosphorylation] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 5 Text feature [suppressor] present in test data point [True]
# 6 Text feature [inhibitors] present in test data point [True]
# 7 Text feature [function] present in test data point [True]
# 8 Text feature [activated] present in test data point [True]
# 9 Text feature [constitutive] present in test data point [True]
# 12 Text feature [treatment] present in test data point [True]
# 13 Text feature [inhibitor] present in test data point [True]
# 14 Text feature [loss] present in test data point [True]
# 15 Text feature [oncogenic] present in test data point [True]
# 18 Text feature [therapy] present in test data point [True]
# 19 Text feature [pten] present in test data point [True]
# 20 Text feature [protein] present in test data point [True]
# 22 Text feature [functional] present in test data point [True]
# 24 Text feature [constitutively] present in test data point [True]
# 28 Text feature [receptor] present in test data point [True]
# 31 Text feature [signaling] present in test data point [True]
# 32 Text feature [inhibited] present in test data point [True]
# 34 Text feature [cells] present in test data point [True]
# 35 Text feature [stability] present in test data point [True]
# 39 Text feature [expression] present in test data point [True]
# 41 Text feature [inhibition] present in test data point [True]
# 43 Text feature [growth] present in test data point [True]
# 45 Text feature [treated] present in test data point [True]
# 47 Text feature [57] present in test data point [True]
# 48 Text feature [drug] present in test data point [True]
# 50 Text feature [cell] present in test data point [True]
# 53 Text feature [therapeutic] present in test data point [True]
# 54 Text feature [ic50] present in test data point [True]
# 56 Text feature [proteins] present in test data point [True]
# 58 Text feature [akt] present in test data point [True]
# 62 Text feature [extracellular] present in test data point [True]
# 64 Text feature [ring] present in test data point [True]
# 66 Text feature [resistance] present in test data point [True]
# 68 Text feature [advanced] present in test data point [True]
# 69 Text feature [clinical] present in test data point [True]
# 70 Text feature [predicted] present in test data point [True]
# 72 Text feature [survival] present in test data point [True]
# 73 Text feature [phospho] present in test data point [True]
# 74 Text feature [downstream] present in test data point [True]
# 75 Text feature [sensitivity] present in test data point [True]
# 77 Text feature [patients] present in test data point [True]
# 82 Text feature [assays] present in test data point [True]
# 85 Text feature [nuclear] present in test data point [True]
# 87 Text feature [dna] present in test data point [True]
# 89 Text feature [response] present in test data point [True]
# 90 Text feature [phosphorylated] present in test data point [True]
# 92 Text feature [assay] present in test data point [True]
# 93 Text feature [activity] present in test data point [True]
# 94 Text feature [dose] present in test data point [True]
# 97 Text feature [results] present in test data point [True]
# 98 Text feature [sensitive] present in test data point [True]
# Out of the top  100  features  55 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.018  0.4888 0.0135 0.0126 0.0308 0.03   0.4027 0.0023 0.0013]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [phosphorylation] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 6 Text feature [inhibitors] present in test data point [True]
# 8 Text feature [activated] present in test data point [True]
# 12 Text feature [treatment] present in test data point [True]
# 13 Text feature [inhibitor] present in test data point [True]
# 15 Text feature [oncogenic] present in test data point [True]
# 18 Text feature [therapy] present in test data point [True]
# 20 Text feature [protein] present in test data point [True]
# 22 Text feature [functional] present in test data point [True]
# 25 Text feature [activate] present in test data point [True]
# 26 Text feature [classified] present in test data point [True]
# 28 Text feature [receptor] present in test data point [True]
# 30 Text feature [trials] present in test data point [True]
# 31 Text feature [signaling] present in test data point [True]
# 32 Text feature [inhibited] present in test data point [True]
# 33 Text feature [transforming] present in test data point [True]
# 34 Text feature [cells] present in test data point [True]
# 39 Text feature [expression] present in test data point [True]
# 41 Text feature [inhibition] present in test data point [True]
# 43 Text feature [growth] present in test data point [True]
# 45 Text feature [treated] present in test data point [True]
# 46 Text feature [ba] present in test data point [True]
# 48 Text feature [drug] present in test data point [True]
# 50 Text feature [cell] present in test data point [True]
# 53 Text feature [therapeutic] present in test data point [True]
# 54 Text feature [ic50] present in test data point [True]
# 56 Text feature [proteins] present in test data point [True]
# 57 Text feature [f3] present in test data point [True]
# 63 Text feature [efficacy] present in test data point [True]
# 69 Text feature [clinical] present in test data point [True]
# 70 Text feature [predicted] present in test data point [True]
# 72 Text feature [survival] present in test data point [True]
# 74 Text feature [downstream] present in test data point [True]
# 77 Text feature [patients] present in test data point [True]
# 80 Text feature [ras] present in test data point [True]
# 82 Text feature [assays] present in test data point [True]
# 86 Text feature [classification] present in test data point [True]
# 87 Text feature [dna] present in test data point [True]
# 89 Text feature [response] present in test data point [True]
# 90 Text feature [phosphorylated] present in test data point [True]
# 93 Text feature [activity] present in test data point [True]
# 97 Text feature [results] present in test data point [True]
# 98 Text feature [sensitive] present in test data point [True]
# 99 Text feature [risk] present in test data point [True]
# Out of the top  100  features  48 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 1.1949140859185847
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.0768301110935532
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.0120297088882164
# for n_estimators = 10 and max depth =  10
# Log Loss : 0.9813648270333516
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.1504527746167348
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.0621605843077047
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.005842613881303
# for n_estimators = 50 and max depth =  10
# Log Loss : 0.9755530031138321
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.144370966032171
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.0691558053877872
# for n_estimators = 100 and max depth =  5
# Log Loss : 0.999942816058699
# for n_estimators = 100 and max depth =  10
# Log Loss : 0.9723640402896624
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.1381914085524039
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.0696944640623869
# for n_estimators = 200 and max depth =  5
# Log Loss : 0.999257726716535
# for n_estimators = 200 and max depth =  10
# Log Loss : 0.971747717236161
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.135980466963505
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.0720709275783509
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.0050635565416601
# for n_estimators = 500 and max depth =  10
# Log Loss : 0.9716291180782546
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.1322602843471883
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.0714335209502135
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.0016919964070143
# for n_estimators = 1000 and max depth =  10
# Log Loss : 0.9722261308737181
# For values of best alpha =  500 The train log loss is: 0.4636595913612512
# For values of best alpha =  500 The cross validation log loss is: 0.9716291180782546
# For values of best alpha =  500 The test log loss is: 0.9523945181212365

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 0.9716291180782546
# Number of mis-classified points : 0.3176691729323308
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0324 0.6143 0.0157 0.0315 0.0346 0.1024 0.1606 0.0038 0.0047]]
# Actual Class : 5
# --------------------------------------------------
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0268 0.5486 0.0135 0.0273 0.0288 0.0311 0.3168 0.003  0.0041]]
# Actual Class : 7
# --------------------------------------------------
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.96
# Support vector machines : Log Loss: 1.69
# Naive Bayes : Log Loss: 1.19
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.179
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.046
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.544
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.101
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 0.987
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 0.998

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 1.0511386308286534
# Log loss (CV) on the stacking classifier : 1.1009080455472033
# Log loss (test) on the stacking classifier : 1.1284621907861365
# Number of missclassified point : 0.362406015037594
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 1.0869174718546994
# Log loss (CV) on the VotingClassifier : 1.1527157771725867
# Log loss (test) on the VotingClassifier : 1.1643938796117699
# Number of missclassified point : 0.37142857142857144
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h1>5. Assignments</h1>

# %% [markdown]
# <ol>
#     <li> Apply All the models with tf-idf features (Replace CountVectorizer with tfidfVectorizer and run the same cells)</li>
#     <li> Instead of using all the words in the dataset, use only the top 1000 words based of tf-idf values</li>
#     <li>Apply Logistic regression with CountVectorizer Features, including both unigrams and bigrams</li>
#     <li> Try any of the feature engineering techniques discussed in the course to reduce the CV and test log-loss to a value less than 1.0</li>
# </ol>

# %% [markdown]
# ## 6. Observation :

# %%
from prettytable import PrettyTable

# %%
table = PrettyTable(['Model', 'Data', 'Train Loss', 'CV loss', 'Test loss', 'Mis-classification'])
table.add_row(['Naive Bayes', 'TF IDF',1.06,1.15,1.19,0.37])
table.add_row(['k-NN', 'TF IDF',0.80,1.01,1.04,0.33])
table.add_row(['Logistic Regression(Balanced)', 'TF IDF',0.80,0.94,0.98,0.315])
table.add_row(['Logistic Regression(Balanced)', 'Unigram',0.78,1.09,1.09,0.33])
table.add_row(['Logistic Regression(Balanced)', 'Bigram',0.78,1.19,1.20,0.38])
table.add_row(['Logistic Regression(Imbalanced)', 'TF IDF',0.80,0.97,1.00,0.317])
table.add_row(['Logistic Regression(Imbalanced)', 'Unigram',0.67,1.13,1.08,0.33])
table.add_row(['Logistic Regression(Imbalanced)', 'Bigram',0.77,1.18,1.20,0.36])
table.add_row(['Linear SVM', 'TF IDF',0.95,1.06,1.11,0.32])
table.add_row(['Random Forest(One Hot)', 'TF IDF',0.85,1.21,1.18,0.40])
table.add_row(['Random Forest(Response coding)', 'TF IDF',0.46,0.97,0.95,0.317])
table.add_row(['Stacking', 'TF IDF',1.05,1.10,1.12,0.36])
table.add_row(['Voting', 'TF IDF',1.08,1.15,1.16,0.37])
print(table)
# Out:
# +---------------------------------+---------+------------+---------+-----------+--------------------+
# |              Model              |   Data  | Train Loss | CV loss | Test loss | Mis-classification |
# +---------------------------------+---------+------------+---------+-----------+--------------------+
# |           Naive Bayes           |  TF IDF |    1.06    |   1.15  |    1.19   |        0.37        |
# |               k-NN              |  TF IDF |    0.8     |   1.01  |    1.04   |        0.33        |
# |  Logistic Regression(Balanced)  |  TF IDF |    0.8     |   0.94  |    0.98   |       0.315        |
# |  Logistic Regression(Balanced)  | Unigram |    0.78    |   1.09  |    1.09   |        0.33        |
# |  Logistic Regression(Balanced)  |  Bigram |    0.78    |   1.19  |    1.2    |        0.38        |
# | Logistic Regression(Imbalanced) |  TF IDF |    0.8     |   0.97  |    1.0    |       0.317        |
# | Logistic Regression(Imbalanced) | Unigram |    0.67    |   1.13  |    1.08   |        0.33        |
# | Logistic Regression(Imbalanced) |  Bigram |    0.77    |   1.18  |    1.2    |        0.36        |
# |            Linear SVM           |  TF IDF |    0.95    |   1.06  |    1.11   |        0.32        |
# |      Random Forest(One Hot)     |  TF IDF |    0.85    |   1.21  |    1.18   |        0.4         |
# |  Random Forest(Response coding) |  TF IDF |    0.46    |   0.97  |    0.95   |       0.317        |
# |             Stacking            |  TF IDF |    1.05    |   1.1   |    1.12   |        0.36        |
# |              Voting             |  TF IDF |    1.08    |   1.15  |    1.16   |        0.37        |
# +---------------------------------+---------+------------+---------+-----------+--------------------+

# %% [markdown]
# ## Conclusion:
#
# * Here Logistic regression Balanced , Imbalanced and Random Forest with response coding did a terrific job.
# * They not only reduced log loss below 1.0 but alos mimized mis-classification rate.
# * This assignment helped me helped to how to apply diffrent model on a single dataset as required.
